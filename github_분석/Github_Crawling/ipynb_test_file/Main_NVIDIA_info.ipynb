# %%
import time
from get_github_information_on_keyword import search_information
import requests
import pandas as pd
from fake_useragent import UserAgent
from bs4 import BeautifulSoup as bs
import urllib.request as ur

def main(name):

    df = pd.DataFrame(
            columns=[
                "title",
                "descript",
                "topic_keyword",
                "fork",
                "star",
            ]
        )

    for i in range(1,11): # 한 페이지당 repo 30개씩 추출 가능 
        temp_df = search_information(name,i) #search_information 함수 사용

        df = pd.concat([df,temp_df],ignore_index=True) #여러개의 동일한 형태 DataFrame 합치기 -> 각 페이지 데이터프레임 형태 합침
    return df


if __name__ == "__main__":

    start = time.time()
    result_df = main('NVIDIA')
    result_df.to_csv('test_repo_info.csv',encoding = 'utf-8')
    end = time.time()
    print(result_df)
    print(end - start, " second")
# Out:
#                         title  \
# 0     spark-rapids-benchmarks
# 1                        DALI
# 2                        NeMo
# 3    nvidia-container-toolkit
# 4                  DALI_extra
# ..                        ...
# 295                     WebGL
# 296                     nvgpu
# 297        webgl-path-tracing
# 298                   scenejs
# 299                       tdl
#
#                                               descript  \
# 0    Spark RAPIDS Benchmarks – benchmark sets and u...
# 1    A GPU-accelerated library containing highly op...
# 2                NeMo: a toolkit for conversational AI
# 3      Build and run containers leveraging NVIDIA GPUs
# 4                           Test data for DALI project
# ..                                                 ...
# 295              The Official Khronos WebGL Repository
# 296                                            [BLANK]
# 297                   Path tracing in GLSL using WebGL
# 298  An extensible WebGL-based engine for high-deta...
# 299                          A low-level WebGL library
#
#                                          topic_keyword  fork  star
# 0                                                   []     5    12
# 1    [python, machine-learning, deep-learning, neur...   514  3933
# 2    [nlp, text-to-speech, deep-learning, neural-ne...  1082  4438
# 3                                                   []    33    95
# 4                                                   []    25    25
# ..                                                 ...   ...   ...
# 295                                                 []   653    11
# 296                                                 []    10    13
# 297                                                 []    57    11
# 298                                                 []   177     7
# 299                                                 []    39     3
#
# [300 rows x 5 columns]
# 12.336880207061768  second

# %%
result_df
# Out:
#                         title  \
# 0     spark-rapids-benchmarks
# 1                        DALI
# 2                        NeMo
# 3    nvidia-container-toolkit
# 4                  DALI_extra
# ..                        ...
# 295                     WebGL
# 296                     nvgpu
# 297        webgl-path-tracing
# 298                   scenejs
# 299                       tdl
#
#                                               descript  \
# 0    Spark RAPIDS Benchmarks – benchmark sets and u...
# 1    A GPU-accelerated library containing highly op...
# 2                NeMo: a toolkit for conversational AI
# 3      Build and run containers leveraging NVIDIA GPUs
# 4                           Test data for DALI project
# ..                                                 ...
# 295              The Official Khronos WebGL Repository
# 296                                            [BLANK]
# 297                   Path tracing in GLSL using WebGL
# 298  An extensible WebGL-based engine for high-deta...
# 299                          A low-level WebGL library
#
#                                          topic_keyword  fork  star
# 0                                                   []     5    12
# 1    [python, machine-learning, deep-learning, neur...   514  3933
# 2    [nlp, text-to-speech, deep-learning, neural-ne...  1082  4438
# 3                                                   []    33    95
# 4                                                   []    25    25
# ..                                                 ...   ...   ...
# 295                                                 []   653    11
# 296                                                 []    10    13
# 297                                                 []    57    11
# 298                                                 []   177     7
# 299                                                 []    39     3
#
# [300 rows x 5 columns]
