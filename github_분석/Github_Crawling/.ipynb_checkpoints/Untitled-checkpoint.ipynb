# %%
import time
import requests
import pandas as pd
from fake_useragent import UserAgent
from bs4 import BeautifulSoup as bs
import urllib.request as ur


def search_information(name,page_n):

    df_dic = {}
    dic_keys = ['title','descript','topic_keyword','fork','star']  #레포지토리별 뽑아야 할 자료들
    
    url = 'https://github.com/orgs/{}/repositories?page={}'.format(name,page_n)

    html = ur.urlopen(url)
    soup = bs(html.read(), "html.parser")

    # 이름,별점,블로그,방문자 리뷰
    repository_list = soup.find_all("li", "Box-row") # 제목
    # print(len(repository_list)) # 한페이지당 30개의 repository가 존재 (full일 때)


    for k in dic_keys:  #뽑아야 할 자료들 모두 반복문 통해 추출
        df_dic[k] = []  #각 레포지토리별 자료들 리스트에 담기

    for repo in repository_list:
        title = repo.find('a','d-inline-block').text.strip() # 각 repository별 title 추출

        description = repo.find('p','color-fg-muted mb-0 wb-break-word') # 각 repository별 drcript 추출
        if description is not None:
            descript = description.text.strip()
        else:
            descript = '[BLANK]'

        topic_keyword = repo.find('div','d-inline-flex flex-wrap flex-items-center f6 my-1') #각 repository별 topic keyword 추출

        if topic_keyword is not None:
            topic_keyword_list = []
            for tk in topic_keyword.find_all('a'):
                topic_keyword_list.append(tk.text.strip())
        else:
            topic_keyword_list = []

        get_fork = repo.find('a','Link--muted mr-3') #각 repository별 fork 수 추출

        if get_fork is not None:
            fork = int(get_fork.text.strip().replace(',',''))
        else:
            fork = 0

        get_star = repo.find('a','no-wrap Link--muted mr-3') #각 repository별 star 수 추출

        if get_star is not None:
            star = int(get_star.text.strip().replace(',',''))
        else:
            star = 0


        df_dic['title'].append(title)
        df_dic['descript'].append(descript)
        df_dic['topic_keyword'].append(topic_keyword_list)
        df_dic['fork'].append(fork)
        df_dic['star'].append(star)

        temp_df = pd.DataFrame(df_dic)

    return temp_df

# %%
a = search_information('NVIDIA',1)
a
# Out:
#                            title  \
# 0                           NeMo
# 1                           DALI
# 2                    Megatron-LM
# 3        spark-rapids-benchmarks
# 4                   spark-rapids
# 5                         VisRTX
# 6                           apex
# 7                         thrust
# 8                        NVFlare
# 9   trt-samples-for-hackathon-cn
# 10                       aistore
# 11                     CleanUNet
# 12              spark-rapids-jni
# 13                          warp
# 14                 cuCollections
# 15                       cutlass
# 16               MinkowskiEngine
# 17                          MatX
# 18                cudnn-frontend
# 19          DeepLearningExamples
# 20                          AMGX
# 21                  gpu-operator
# 22         spark-rapids-examples
# 23                     DALI_deps
# 24                    DALI_extra
# 25      VideoProcessingFramework
# 26                        radtts
# 27                          NVTX
# 28                           cub
# 29                       ais-k8s
#
#                                              descript  \
# 0               NeMo: a toolkit for conversational AI
# 1   A GPU-accelerated library containing highly op...
# 2   Ongoing research training transformer models a...
# 3   Spark RAPIDS Benchmarks – benchmark sets and u...
# 4   Spark RAPIDS plugin - accelerate Apache Spark ...
# 5            NVIDIA RTX based implementation of ANARI
# 6   A PyTorch Extension: Tools for easy mixed prec...
# 7                The C++ parallel algorithms library.
# 8   NVIDIA Federated Learning Application Runtime ...
# 9             Simple samples for TensorRT programming
# 10      AIStore: scalable storage for AI applications
# 11  Official PyTorch Implementation of CleanUNet (...
# 12            RAPIDS Accelerator JNI For Apache Spark
# 13  A Python framework for high performance GPU si...
# 14                                            [BLANK]
# 15      CUDA Templates for Linear Algebra Subroutines
# 16  Minkowski Engine is an auto-diff neural networ...
# 17  An efficient C++17 GPU numerical computing lib...
# 18  cudnn_frontend provides a c++ wrapper for the ...
# 19                             Deep Learning Examples
# 20  Distributed multigrid linear solver library on...
# 21  NVIDIA GPU Operator creates/configures/manages...
# 22  A repo for all spark examples using Rapids Acc...
# 23            3rd party dependencies for DALI project
# 24                         Test data for DALI project
# 25  Set of Python bindings to C++ libraries which ...
# 26  Provides training, inference and voice convers...
# 27  The NVIDIA® Tools Extension SDK (NVTX) is a C-...
# 28               Cooperative primitives for CUDA C++.
# 29  Kubernetes Operator, helm charts, and producti...
#
#                                         topic_keyword  fork  star
# 0   [nlp, text-to-speech, deep-learning, neural-ne...  1082  4433
# 1   [python, machine-learning, deep-learning, neur...   515  3929
# 2                                                  []   622  3066
# 3                                                  []     5    12
# 4                      [big-data, gpu, rapids, spark]   148   436
# 5                                                  []    17   170
# 6                                                  []  1029  6476
# 7   [cxx, algorithms, cpp, gpu, cpp14, cpp11, nvidia]   683  4018
# 8                                            [python]    49   209
# 9                                                  []   143   426
# 10  [deep-learning, etl, high-performance, hyper-c...    67   629
# 11             [speech-denoising, speech-enchacement]     9    78
# 12                                                 []    21    12
# 13                                                 []    41   610
# 14                                                 []    41   152
# 15  [deep-learning, cpp, cpp11, nvidia, deep-learn...   361  1928
# 16  [computer-vision, deep-learning, cuda, high-di...   240  1651
# 17             [hpc, gpu, cuda, gpgpu, gpu-computing]    35   513
# 18                                                 []    23   104
# 19                                                 []  2401  8683
# 20                                                 []   107   288
# 21                    [kubernetes, gpu, cuda, nvidia]   130   576
# 22                                                 []    25    33
# 23                                                 []    14     6
# 24                                                 []    25    25
# 25                                                 []   153   829
# 26                                                 []     5   131
# 27                                                 []    13    60
# 28  [cxx, algorithms, cpp, gpu, cpp14, cpp11, nvidia]   384  1218
# 29                                                 []     3    28
