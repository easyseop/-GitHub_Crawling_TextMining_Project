# %%
import time
from unittest import result
from get_github_repository_contributor import get_contributor
from bs4 import BeautifulSoup as bs
import urllib.request as ur
import pandas as pd
import itertools

def search_title(name,page_n):
    
    df_dic = []
    
    url = 'https://github.com/orgs/{}/repositories?page={}'.format(name,page_n)

    html = ur.urlopen(url)
    soup = bs(html.read(), "html.parser")

    # 이름,별점,블로그,방문자 리뷰
    repository_list = soup.find_all("li", "Box-row") # 제목
    
    for repo in repository_list:
        title = repo.find('a','d-inline-block').text.strip()
        
        df_dic.append(title)
        temp_df = df_dic
        
    return temp_df

def main(name):
    title_list =[]
    for i in range(1,11):
        temp_df = search_title(name,i)
        title_list.append(temp_df)
    return title_list

# %%
result_df = main('NVIDIA')
result_df_2 = list(itertools.chain(*result_df))
print(result_df_2)
# Out:
# ['MatX', 'DALI', 'aistore', 'spark-rapids', 'NeMo', 'spark-rapids-benchmarks', 'nvidia-container-toolkit', 'DALI_extra', 'nccl', 'open-gpu-kernel-modules', 'spark-rapids-jni', 'spark-rapids-examples', 'apex', 'NVFlare', 'open-gpu-doc', 'cuCollections', 'go-nvml', 'cloud-native-core', 'k8s-device-plugin', 'mig-parted', 'Megatron-LM', 'VisRTX', 'thrust', 'trt-samples-for-hackathon-cn', 'CleanUNet', 'warp', 'cutlass', 'MinkowskiEngine', 'cudnn-frontend', 'DeepLearningExamples', 'AMGX', 'gpu-operator', 'DALI_deps', 'VideoProcessingFramework', 'radtts', 'NVTX', 'cub', 'ais-k8s', 'cuda-repo-management', 'cuda-samples', 'cheminformatics', 'deepops', 'egl-wayland', 'nvidia-settings', 'FasterTransformer', 'libcudacxx', 'pyxis', 'edk2', 'edk2-platforms', 'edk2-edkrepo-manifest', 'edk2-nvidia', 'libglvnd', 'DLSS', 'swift', 'spark-rapids-ml', 'nvcomp', 'runx', 'hpc-container-maker', 'cuda-python', 'enroot', 'container-canary', 'grcuda', 'dcgm-exporter', 'vgpu-device-manager', 'jetson-gpio', 'nvidia-xconfig', 'nvidia-persistenced', 'nvidia-modprobe', 'nvidia-installer', 'nvindex-cloud', 'zypper-packaging-nvidia-driver', 'yum-packaging-precompiled-kmod', 'yum-packaging-nvidia-xconfig', 'yum-packaging-nvidia-settings', 'yum-packaging-nvidia-persistenced', 'yum-packaging-nvidia-modprobe', 'yum-packaging-nvidia-kmod-common', 'yum-packaging-nvidia-driver', 'yum-packaging-dkms-nvidia', 'go-dcgm', 'jitify', 'TensorRT', 'cuDecomp', 'clara-dicom-adapter', 'DL4AGX', 'GPUStressTest', 'DCGM', 'kubevirt-gpu-device-plugin', 'energy-sdk-l2rpn', 'Bobber', 'Imageinary', 'flowtron', 'waveglow', 'tacotron2', 'vagrant-swift-all-in-one', 'sparkucx', 'nvidia-docker', 'libnvidia-container', 'nvbench', 'clara-holoscan-embedded-sdk', 'CUDALibrarySamples', 'MDL-SDK', 'nsight-aftermath-samples', 'nvidia-container-runtime', 'mpi-acx', 'clara-holoscan', 'gpu-feature-discovery', 'MagnumIO', 'energy-sdk', 'gds-nvidia-fs', 'ansible-role-nvidia-driver', 'edk2-nvidia-non-osi', 'Q2RTX', 'ngc-container-replicator', 'cuQuantum', 'BigVGAN', 'DIGITS', 'GPUPowerTest', 'nsight-vscode-edition', 'gitlab-answer-app', 'ai-assisted-annotation-client', 'clara-train-examples', 'tensorflow', 'nvbandwidth', 'nccl-tests', 'mellotron', 'nvscic2c', 'FFmpeg-GPU-Demo', 'nephele-packages', 'pix2pixHD', 'cccl', 'vid2vid', 'CloudXR', 'ais-etl', 'compute-sanitizer-samples', 'data-science-blueprints', 'clara-ia', 'proxyfs', 'clara-holoscan-perf-tools', 'jetson-rdma-picoevb', 'framework-determinism', 'multi-gpu-programming-models', 'ansible-collection-dpu-ops', 'yum-packaging-nvidia-plugin', 'flownet2-pytorch', 'OptiX_Apps', 'spark-xgboost', 'transformer-ls', 'l2fwd-nv', 'gdrcopy', 'nvtx-plugins', 'go-gpuallocator', 'fsi-samples', 'MAXINE-AFX-SDK', 'nvaitc-toolkit', 'dllogger', 'clara-viz', 'cocoapi', 'gbm-bench', 'ansible-role-nvidia-docker', 'nvidia-gcp-samples', 'speechsquad', '5t5g', 'rtx_compute_samples', 'nephele', 'dgx-selinux', 'O-RAN-Archive', 'nsight-training', 'blossom-action', 'fission', 'gvdb-voxels', 'ansible-role-enroot', 'nvbench_demo', 'egl-gbm', 'container-config', 'partialconv', 'ngc-container-environment-modules', 'GTC-2021-A31202-Code', 'gpu-monitoring-tools', 'Eigensolver_gpu', 'FastPhotoStyle', 'clara-platform-python-client', 'data-science-stack', 'retinanet-examples', 'clara-pipeline-operator-sizing-tool', 'ProViz-AI-Samples', 'spark-xgboost-examples', 'build-system-archive-import-examples', 'MAXINE-AR-SDK', 'MAXINE-VFX-SDK', 'sortedmap', 'clara-platform-ansible-playbooks', 'tensorrt-laboratory', 'caffe', 'cstruct', 'semantic-segmentation', 'yum-packaging-fabric-manager', 'PyProf', 'NVIDIAOpticalFlowSDK', 'apt-packaging-fabric-manager', 'fleet-command', 'mcmc-bnn-example', 'ipyparaview', 'Dataset_Utilities', 'DeepRecommender', 'nebula-nsight', 'OpenSeq2Seq', 'rapidAligner', 'cuda-cpp-grammar', 'docker-swift', 'ubuntu-packaging-nvidia-driver', 'apt-packaging-libnvidia-nscq', 'yum-packaging-libnvidia-nscq', 'ubuntu-packaging-nvidia-settings', 'ubuntu-packaging-nvidia-modprobe', ...

# %%
def main(cor_name,repo_name):
    url = f'https://github.com/{cor_name}/{repo_name}/graphs/contributors'
    dataframe = get_contributor(url)
    return dataframe

# %%
for j in result_df_2:
    
    print(j)
    result_df = main('NVIDIA',j)
    
    (result_df.to_csv(f'NVIDIA_{j}_contributors.csv',encoding='utf-8-sig',index=False))
# Out:
# MatX
# done
# DALI
# done
# aistore
# done
# spark-rapids
# done
# NeMo
# done
# spark-rapids-benchmarks
# done
# nvidia-container-toolkit
# done
# DALI_extra
# done
# nccl
# done
# open-gpu-kernel-modules
# done
# spark-rapids-jni
# done
# spark-rapids-examples
# done
# apex
# done
# NVFlare
# done
# open-gpu-doc
# done
# cuCollections
# done
# go-nvml
# done
# cloud-native-core
# done
# k8s-device-plugin
# done
# mig-parted
# done
# Megatron-LM
# done
# VisRTX
# done
# thrust
# done
# trt-samples-for-hackathon-cn
# done
# CleanUNet
# done
# warp
# done
# cutlass
# done
# MinkowskiEngine
# done
# cudnn-frontend
# done
# DeepLearningExamples
# done
# AMGX
# done
# gpu-operator
# done
# DALI_deps
# done
# VideoProcessingFramework
# done
# radtts
# done
# NVTX
# done
# cub
# done
# ais-k8s
# done
# cuda-repo-management
# done
# cuda-samples
# done
# cheminformatics
# done
# deepops
# done
# egl-wayland
# done
# nvidia-settings
# done
# FasterTransformer
# done
# libcudacxx
# done
# pyxis
# done
# edk2
# done
# edk2-platforms
# done
# edk2-edkrepo-manifest
# done
# edk2-nvidia
# done
# libglvnd
# done
# DLSS
# done
# swift
# done
# spark-rapids-ml
# done
# nvcomp
# done
# runx
# done
# hpc-container-maker
# done
# cuda-python
# done
# enroot
# done
# container-canary
# done
# grcuda
# done
# dcgm-exporter
# done
# vgpu-device-manager
# done
# jetson-gpio
# done
# nvidia-xconfig
# done
# nvidia-persistenced
# done
# nvidia-modprobe
# done
# nvidia-installer
# done
# nvindex-cloud
# done
# zypper-packaging-nvidia-driver
# done
# yum-packaging-precompiled-kmod
# done
# yum-packaging-nvidia-xconfig
# done
# yum-packaging-nvidia-settings
# done
# yum-packaging-nvidia-persistenced
# done
# yum-packaging-nvidia-modprobe
# done
# yum-packaging-nvidia-kmod-common
# done
# yum-packaging-nvidia-driver
# done
# yum-packaging-dkms-nvidia
# done
# go-dcgm
# done
# jitify
# done
# TensorRT
# done
# cuDecomp
# done
# clara-dicom-adapter
# done
# DL4AGX
# done
# GPUStressTest
# done
# DCGM
# done
# kubevirt-gpu-device-plugin
# done
# energy-sdk-l2rpn
# done
# Bobber
# done
# Imageinary
# done
# flowtron
# done
# waveglow
# done
# tacotron2
# done
# vagrant-swift-all-in-one
# done
# sparkucx
# done
# nvidia-docker
# done
# libnvidia-container
# done
# nvbench
# done
# clara-holoscan-embedded-sdk
# done
# CUDALibrarySamples
# done
# MDL-SDK
# done
# nsight-aftermath-samples
# done
# nvidia-container-runtime
# done
# mpi-acx
# done
# clara-holoscan
# done
# gpu-feature-discovery
# done
# MagnumIO
# done
# energy-sdk
# done
# gds-nvidia-fs
# done
# ansible-role-nvidia-driver
# done
# edk2-nvidia-non-osi
# done
# Q2RTX
# done
# ngc-container-replicator
# done
# cuQuantum
# done
# BigVGAN
# done
# DIGITS
# done
# GPUPowerTest
# done
# nsight-vscode-edition
# done
# gitlab-answer-app
# done
# ai-assisted-annotation-client
# done
# clara-train-examples
# done
# tensorflow
# done
# nvbandwidth
# done
# nccl-tests
# done
# mellotron
# done
# nvscic2c
# done
# FFmpeg-GPU-Demo
# done
# nephele-packages
# done
# pix2pixHD
# done
# cccl
# done
# vid2vid
# done
# CloudXR
# done
# ais-etl
# done
# compute-sanitizer-samples
# done
# data-science-blueprints
# done
# clara-ia
# done
# proxyfs
# done
# clara-holoscan-perf-tools
# done
# jetson-rdma-picoevb
# done
# framework-determinism
# done
# multi-gpu-programming-models
# done
# ansible-collection-dpu-ops
# done
# yum-packaging-nvidia-plugin
# done
# flownet2-pytorch
# done
# OptiX_Apps
# done
# spark-xgboost
# done
# transformer-ls
# done
# l2fwd-nv
# done
# gdrcopy
# done
# nvtx-plugins
# done
# go-gpuallocator
# done
# fsi-samples
# done
# MAXINE-AFX-SDK
# done
# nvaitc-toolkit
# done
# dllogger
# done
# clara-viz
# done
# cocoapi
# done
# gbm-bench
# done
# ansible-role-nvidia-docker
# done
# nvidia-gcp-samples
# done
# speechsquad
# done
# 5t5g
# done
# rtx_compute_samples
# done
# nephele
# done
# dgx-selinux
# done
# O-RAN-Archive
# done
# nsight-training
# done
# blossom-action
# done
# fission
# done
# gvdb-voxels
# done
# ansible-role-enroot
# done
# nvbench_demo
# done
# egl-gbm
# done
# container-config
# done
# partialconv
# done
# ngc-container-environment-modules
# done
# GTC-2021-A31202-Code
# done
# gpu-monitoring-tools
# done
# Eigensolver_gpu
# done
# FastPhotoStyle
# done
# clara-platform-python-client
# done
# data-science-stack
# done
# retinanet-examples
# done
# clara-pipeline-operator-sizing-tool
# done
# ProViz-AI-Samples
# done
# spark-xgboost-examples
# done
# build-system-archive-import-examples
# done
# MAXINE-AR-SDK
# done
# MAXINE-VFX-SDK
# done
# sortedmap
# done
# clara-platform-ansible-playbooks
# done
# tensorrt-laboratory
# done
# caffe
# done
# cstruct
# done
# semantic-segmentation
# done
# yum-packaging-fabric-manager
# done
# PyProf
# done
# NVIDIAOpticalFlowSDK
# done
# apt-packaging-fabric-manager
# done
# fleet-command
# done
# mcmc-bnn-example
# done
# ipyparaview
# done
# Dataset_Utilities
# done
# DeepRecommender
# done
# nebula-nsight
# done
# OpenSeq2Seq
# done
# rapidAligner
# done
# cuda-cpp-grammar
# done
# docker-swift
# done
# ubuntu-packaging-nvidia-driver
# done
# apt-packaging-libnvidia-nscq
# done
# yum-packaging-libnvidia-nscq
# done
# ubuntu-packaging-nvidia-settings
# done
# ubuntu-packaging-nvidia-modprobe
# done
# python-jetson
# done
# swiftstack-collectd-plugin
# done
# object-detection-tensorrt-example
# done
# healthcare-on-tap-TRT-TRITON-demo
# done
# swiftstack-collectd
# done
# proxyfs-vfs
# done
# proxyfs-jrpc-client
# done
# dw-ros
# done
# nv-wavenet
# done
# doroce-linux
# done
# Dataset_Synthesizer
# done
# GraphQSat
# done
# three.js
# done
# sampleQAT
# done
# ising-gpu
# done
# go-tfdata
# done
# kmeans
# done
# sentiment-discovery
# done
# PixelView
# done
# NvPipe
# done
# ContrastiveLosses4VRD
# done
# UnsupervisedLandmarkLearning
# done
# unsupervised-video-interpolation
# done
# cuda-profiler
# done
# vdisc
# done
# cbootimage
# done
# video-sdk-samples
# done
# tegra-pinmux-scripts
# done
# eglexternalplatform
# done
# NVSM
# done
# dlinput-tf
# done
# Korgi
# done
# url-polyfill
# done
# nvvl
# done
# nvstrings
# done
# cbootimage-configs
# done
# cnmem
# done
# Milano
# done
# ngc-examples
# done
# mxnet_to_onnx
# done
# online-softmax
# done
# gpu-rest-engine
# done
# winex_lgpl
# done
# pynvrtc
# done
# tegrarcm
# done
# onnx-tensorrt
# done
# ADLR
# done
# df-nvshmem-prototype
# done
# packer-builder-xenserver
# done
# presto-mapd-connector
# done
# kokkos
# done
# nvidia-query-resource-opengl
# done
# docker-distribution
# done
# Falcor
# done
# SKA-gpu-multiscale-clean
# done
# docker-volume-netshare
# done
# SKA-gpu-grid
# done
# torch-cudnn
# done
# tegra-uboot-flasher-scripts
# done
# tegra-rootfs-scripts
# done
# tegra-nouveau-rootfs
# done
# PRBench
# done
# CoMD-CUDA
# done
# torch-android
# done
# torch-distro
# done
# torch-cutorch
# done
# torch-cunn
# done
# tegra-uboot-scripts
# done
# SKA-gpu-degrid
# done
# SKA-gpu-stefcal
# done
# Forma
# done
# SKA-gpu-direct-convolve
# done
# SKA-gpu-reproject
# done
# torch-nccl
# done
# remorac
# done
# vdpau-hevc-example
# done
# cuda-gdb
# done
# vdpau-win-x11
# done
# cpu-microcode
# done
# tegra-uboot-flasher-manifests
# done
# WebGL
# done
# nvgpu
# done
# webgl-path-tracing
# done
# scenejs
# done
# tdl
# done
